# %% [markdown]
# ### LangChain Version V1

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KET"] = os.getenv("OPENAI_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import os
#       2 from dotenv import load_dotenv
#       3 load_dotenv()
#       4
# ----> 5 os.environ["OPENAI_API_KET"] = os.getenv("OPENAI_API_KEY")
#
# File <frozen os>:722, in _Environ.__setitem__(self, key, value)
#     720 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen os>:782, in _createenviron.<locals>.check_str(value)
#     780 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: str expected, not NoneType
